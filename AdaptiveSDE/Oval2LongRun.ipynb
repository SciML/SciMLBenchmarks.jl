# %%
using StochasticDiffEq, DiffEqProblemLibrary
srand(200)
prob = oval2ModelExample(largeFluctuations=true,useBigs=false)
## Big Run

@inline prog_mess(dt,t,u) = "dt="*string(dt)*
                            "\nt="*string(t)*
                            "\nEcad="*string(u[16])*
                            "\nVim="*string(u[17])
# Out:
# WARNING: Method definition prog_mess(Any, Any, Any) in module Main at In[1]:6 overwritten at In[12]:6.
# prog_mess (generic function with 1 method)

# %%
srand(200)
@time sol = solve(prob,SRIW1(),dt=(1/2)^(18),progress_steps=Int(1e5),
          adaptivealg=:RSwM3,progress=true,qmax=1.125,
          progress_message = prog_mess,
          timeseries_steps=1000,abstol=1e-5,reltol=1e-3);
# Out:
#  15.238692 seconds (41.58 M allocations: 5.262 GB, 5.55% gc time)

# %%
println(maximum(sol[:,2]))
using Plots; gr()
lw = 2
lw2 = 3
p1 = plot(sol.t,sol[:,16],top_margin=50px,
          title="(A) Timeseries of Ecad Concentration",xguide="Time (s)",
          yguide="Concentration",guidefont=font(16),tickfont=font(16),
          linewidth=lw,left_margin=85px,leg=false)
# Out:
# 127.54961357481852
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 160.556,351.619 596.063,351.619 596.063,69.4444 160.556,69.4444
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="160" y="69" width="436" height="283"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   160.556,347.386 160.556,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   247.657,347.386 247.657,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   334.759,347.386 334.759,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   421.86,347.386 421.86,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   508.962,347.386 508.962,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,347.386 596.063,73.6771
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   167.088,293.958 589.53,293.958
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   167.088,213.396 589.53,213.396
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   167.088,132.834 589.53,132.834
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,351.619 596.063,351.619
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,351.619 160.556,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   247.657,351.619 247.657,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   334.759,351.619 334.759,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   421.86,351.619 421.86,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   508.962,351.619 508.962,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,351.619 596.063,347.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,351.619 160.556,69.4444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,293.958 167.088,293.958
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,213.396 167.088,213.396
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   160.556,132.834 167.088,132.834
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 160.556, 373.219)" x="160.556" y="373.219">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 247.657, 373.219)" x="247.657" y="373.219">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 334.759, 373.219)" x="334.759" y="373.219">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 421.86, 373.219)" x="421.86" y="373.219">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 508.962, 373.219)" x="508.962" y="373.219">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 596.063, 373.219)" x="596.063" y="373.219">500</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:end;" transform="rotate(0, 159.356, 302.458)" x="159.356" y="302.458">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:end;" transform="rotate(0, 159.356, 221.896)" x="159.356" y="221.896">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:end;" transform="rotate(0, 159.356, 141.334)" x="159.356" y="141.334">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 378.309, 18)" x="378.309" y="18">(A) Timeseries of Ecad Concentration</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(0, 378.309, 396.6)" x="378.309" y="396.6">Time (s)</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:23; text-anchor:middle;" transform="rotate(-90, 20.4, 210.531)" x="20.4" y="210.531">Concentration</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:1.6; stroke-opacity:1; fill:none" points="
#   160.556,294.007 160.604,294.007 160.648,294.008 160.763,294.01 160.812,294.012 160.845,294.013 160.885,294.014 160.929,294.016 160.965,294.018 160.994,294.02
#   161.048,294.023 161.069,294.025 161.087,294.027 161.119,294.03 161.135,294.031 161.152,294.033 161.199,294.039 161.258,294.046 161.285,294.051 161.312,294.055
#   82.0223,249.792 82.4125,249.374 82.7558,249.221 83.1274,249.257 83.5252,249.699 83.8559,250.368 84.2358,251.279 84.5127,251.97 84.7457,252.599 85.0386,253.445
#   85.3579,254.301 85.6343,255.08 85.9088,255.93 86.2261,256.967 86.4102,257.447 86.504,257.609 86.6835,257.837 86.9524,258.169 87.2075,258.587 87.5017,259.227
#   87.7233,259.778 87.9146,260.204 88.0851,260.429 88.2449,260.573 88.4489,260.727 88.7321,260.98 89.0558,261.473 89.383,262.255 89.6859,263.188 89.9829,264.167
#   90.2427,265.025 90.4949,265.879 90.6697,266.483 90.9033,267.304 91.1201,268.071 91.3309,268.814 91.5256,269.494 91.7408,270.241 91.9308,270.887 92.1187,271.532
#   92.2951,272.139 92.494,272.814 92.9228,273.96 93.0829,274.302 93.3208,274.661 93.5227,274.939 93.6606,275.065 93.8632,275.208 94.1221,275.473 94.3556,275.785
#   94.6036,276.218 94.

# %%
prob.tspan = (0.0,1.0)
## Little Run
sol = solve(prob,EM(),dt=(1/2)^(20),
          progressbar=true,timeseries_steps=1000)
println("EM")
@time sol = solve(prob,EM(),dt=(1/2)^(20),
          progressbar=true,timeseries_steps=1000)

sol = solve(prob,SRI(),dt=(1/2)^(18),adaptive=false,
          progressbar=true,save_timeseries=false)
println("SRI")
@time sol = solve(prob,SRI(),dt=(1/2)^(18),adaptive=false,
          progressbar=true,save_timeseries=false)

sol = solve(prob,SRIW1(),dt=(1/2)^(18),adaptive=false,
          adaptivealg=:RSwM3,progressbar=false,qmax=4,timeseries_steps=1000)
println("SRIW1")
@time sol = solve(prob,SRIW1(),dt=(1/2)^(18),adaptive=false,
          adaptivealg=:RSwM3,progressbar=false,qmax=4,timeseries_steps=1000)

sol = solve(prob,SRI(),dt=(1/2)^(18),
          adaptivealg=:RSwM3,progressbar=false,qmax=1.125,
          timeseries_steps=1000,abstol=1e-6,reltol=1e-4)
println("SRI Adaptive")
@time sol = solve(prob,SRI(),dt=(1/2)^(18),
          adaptivealg=:RSwM3,progressbar=false,qmax=1.125,
          timeseries_steps=1000,abstol=1e-6,reltol=1e-4)
@show length(sol.t)

sol = solve(prob,SRIW1(),dt=(1/2)^(18),
          adaptivealg=:RSwM3,progressbar=false,qmax=1.125,
          timeseries_steps=1000,abstol=1e-6,reltol=1e-4)
println("SRIW1 Adaptive")
@time sol = solve(prob,SRIW1(),dt=(1/2)^(18),
          adaptivealg=:RSwM3,progressbar=false,qmax=1.125,
          timeseries_steps=1000,abstol=1e-6,reltol=1e-4)
@show length(sol.t)
# Out:
# EM
#   1.043666 seconds (20.97 M allocations: 944.596 MB, 12.39% gc time)
# SRI
#   2.035000 seconds (19.92 M allocations: 2.215 GB, 18.66% gc time)
# SRIW1
#   0.438274 seconds (5.24 M allocations: 236.171 MB, 9.18% gc time)
# SRI Adaptive
#   0.191483 seconds (1.47 M allocations: 201.985 MB, 15.81% gc time)
# length(sol.t) = 26
# SRIW1 Adaptive
#   0.022187 seconds (53.55 k allocations: 6.924 MB)
# length(sol.t) = 13
# 13
