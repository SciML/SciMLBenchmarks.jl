# %% [markdown]
# # SDE Work-Precision Diagrams
#
# In this notebook we will run some simple work-precision diagrams for the SDE integrators. These problems are additive and diagonal noise SDEs which can utilize the specialized Rossler methods. These problems are very well-behaved, meaning that adaptive timestepping should not be a significant advantage (unlike more difficult and realistic problems). Thus these tests will measure both the efficiency gains of the Rossler methods along with the overhead of adaptivity.

# %%
using StochasticDiffEq, Plots, DiffEqDevTools, DiffEqProblemLibrary
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# In this notebook, the error that will be measured is the strong error. The strong error is defined as
#
# $$ E = \mathbb{E}[Y_\delta(t) - Y(t)] $$
#
# where $Y_\delta$ is the numerical approximation to $Y$. This is the same as saying, for a given Wiener trajectory $W(t)$, how well does the numerical trajectory match the real trajectory? Note that this is not how well the mean or other moments match the true mean/variance/etc. (that's the weak error), this is how close the trajectory is to the true trajectory which is a stronger notion. In a sense, this is measuring convergence, rather than just convergence in distribution.

# %% [markdown]
# ### Additive Noise Problem
#
# \begin{equation}
# dX_{t}=\left(\frac{\beta}{\sqrt{1+t}}-\frac{1}{2\left(1+t\right)}X_{t}\right)dt+\frac{\alpha\beta}{\sqrt{1+t}}dW_{t},\thinspace\thinspace\thinspace X_{0}=\frac{1}{2}
# \end{equation}
# where $\alpha=\frac{1}{10}$ and $\beta=\frac{1}{20}$. Actual Solution:
# \begin{equation}
# X_{t}=\frac{1}{\sqrt{1+t}}X_{0}+\frac{\beta}{\sqrt{1+t}}\left(t+\alpha W_{t}\right).
# \end{equation}

# %% [markdown]
# First let's solve this using a system of SDEs, repeating this same problem 4 times.

# %%
prob = prob_sde_additivesystem
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]
setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>SRIW1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          Dict(:alg=>SRA1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          Dict(:alg=>SRA1())
          ]
names = ["SRIW1","EM","RKMil","SRIW1 Fixed","SRA1 Fixed","SRA1"]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,names=names,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3000)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   79.355,360.065 79.355,11.811
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   214.069,360.065 214.069,11.811
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   348.783,360.065 348.783,11.811
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   483.497,360.065 483.497,11.811
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,331.453 580.315,331.453
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,231.463 580.315,231.463
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,131.474 580.315,131.474
#   "/>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,31.4836 580.315,31.4836
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   79.355,360.065 79.355,354.842
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   214.069,360.065 214.069,354.842
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   348.783,360.065 348.783,354.842
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   483.497,360.065 483.497,354.842
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,331.453 81.2297,331.453
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,231.463 81.2297,231.463
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,131.474 81.2297,131.474
#   "/>
# <polyline clip-path="url(#clip3000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,31.4836 81.2297,31.4836
#   "/>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 63.2609, 378.817)" x="63.2609" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 76.4402, 371.965)" x="76.4402" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 82.0639, 371.965)" x="82.0639" y="371.965">10 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 200.652, 378.817)" x="200.652" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 213.831, 371.965)" x="213.831" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 219.455, 371.965)" x="219.455" y="371.965">8 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 335.366, 378.817)" x="335.366" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 348.545, 371.965)" x="348.545" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 354.169, 371.965)" x="354.169" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 470.08, 378.817)" x="470.08" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 483.259, 371.965)" x="483.259" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 488.883, 371.965)" x="488.883" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 337.385)" x="32.7642" y="337.385">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9435, 330.533)" x="45.9435" y="330.533">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.5672, 330.533)" x="51.5672" y="330.533">3.5 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 237.395)" x="32.7642" y="237.395">10</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9435, 230.543)" x="45.9435" y="230.543">-</text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.5672, 230.543)" x="51.5672" y="230.543">3.0 </text>
# </g>
# <g clip-path="url(#clip3000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helve

# %%
prob = prob_sde_additivesystem
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]
setups = [
          Dict(:alg=>SRA1())
          Dict(:alg=>SRA2())
          Dict(:alg=>SRA3())
          Dict(:alg=>SOSRA())
          Dict(:alg=>SOSRA2())
          ]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   132.371,360.065 132.371,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.2,360.065 212.2,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.029,360.065 292.029,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.858,360.065 371.858,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   451.687,360.065 451.687,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   531.515,360.065 531.515,11.811
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,296.949 580.315,296.949
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,233.771 580.315,233.771
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,170.592 580.315,170.592
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,107.414 580.315,107.414
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,44.236 580.315,44.236
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   132.371,360.065 132.371,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.2,360.065 212.2,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.029,360.065 292.029,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.858,360.065 371.858,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   451.687,360.065 451.687,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   531.515,360.065 531.515,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,296.949 81.2297,296.949
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,233.771 81.2297,233.771
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,170.592 81.2297,170.592
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,107.414 81.2297,107.414
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,44.236 81.2297,44.236
#   "/>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 116.277, 378.817)" x="116.277" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 129.457, 371.965)" x="129.457" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 135.08, 371.965)" x="135.08" y="371.965">10 </text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 198.783, 378.817)" x="198.783" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 211.962, 371.965)" x="211.962" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 217.586, 371.965)" x="217.586" y="371.965">9 </text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 278.612, 378.817)" x="278.612" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 291.791, 371.965)" x="291.791" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 297.415, 371.965)" x="297.415" y="371.965">8 </text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 358.441, 378.817)" x="358.441" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 371.62, 371.965)" x="371.62" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 377.244, 371.965)" x="377.244" y="371.965">7 </text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 438.269, 378.817)" x="438.269" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 451.449, 371.965)" x="451.449" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size

# %% [markdown]
# Now as a scalar SDE.

# %%
prob = prob_sde_additive
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]



setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>SRIW1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          Dict(:alg=>SRA1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          Dict(:alg=>SRA1())
          ]
names = ["SRIW1","EM","RKMil","SRIW1 Fixed","SRA1 Fixed","SRA1"]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,names=names,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 80.219,360.065 580.315,360.065 580.315,11.811 80.219,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="80" y="11" width="501" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.225,360.065 102.225,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   228.552,360.065 228.552,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   354.88,360.065 354.88,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.208,360.065 481.208,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,323.613 580.315,323.613
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,277.589 580.315,277.589
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,231.564 580.315,231.564
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,185.54 580.315,185.54
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,139.516 580.315,139.516
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,93.4918 580.315,93.4918
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,47.4676 580.315,47.4676
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,360.065 80.219,11.811
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.225,360.065 102.225,354.842
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   228.552,360.065 228.552,354.842
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   354.88,360.065 354.88,354.842
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.208,360.065 481.208,354.842
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,323.613 87.7205,323.613
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,277.589 87.7205,277.589
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,231.564 87.7205,231.564
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,185.54 87.7205,185.54
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,139.516 87.7205,139.516
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,93.4918 87.7205,93.4918
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,47.4676 87.7205,47.4676
#   "/>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 86.1306, 378.817)" x="86.1306" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 99.3099, 371.965)" x="99.3099" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 104.934, 371.965)" x="104.934" y="371.965">10 </text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 215.135, 378.817)" x="215.135" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 228.315, 371.965)" x="228.315" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 233.938, 371.965)" x="233.938" y="371.965">8 </text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 341.463, 378.817)" x="341.463" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 354.642, 371.965)" x="354.642" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 360.266, 371.965)" x="360.266" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 467.791, 378.817)" x="467.791" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 480.97, 371.965)" x="480.97" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 486.594, 371.965)" x="486.594" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 33.9998, 329.545)" x="33.9998" y="329.545">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 47.179, 322.692)" x="47.179" y="322.692">-</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anc

# %%
prob = prob_sde_additive
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]
setups = [
          Dict(:alg=>SRA1())
          Dict(:alg=>SRA2())
          Dict(:alg=>SRA3())
          Dict(:alg=>SOSRA())
          Dict(:alg=>SOSRA2())
          ]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   136.496,360.065 136.496,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   201.769,360.065 201.769,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   267.043,360.065 267.043,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   332.317,360.065 332.317,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   397.591,360.065 397.591,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   462.864,360.065 462.864,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   528.138,360.065 528.138,11.811
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,328.974 580.315,328.974
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,234.991 580.315,234.991
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,141.009 580.315,141.009
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,47.0273 580.315,47.0273
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   136.496,360.065 136.496,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   201.769,360.065 201.769,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   267.043,360.065 267.043,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   332.317,360.065 332.317,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   397.591,360.065 397.591,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   462.864,360.065 462.864,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   528.138,360.065 528.138,354.842
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,328.974 81.2297,328.974
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,234.991 81.2297,234.991
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,141.009 81.2297,141.009
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,47.0273 81.2297,47.0273
#   "/>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 120.402, 378.817)" x="120.402" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 133.581, 371.965)" x="133.581" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 139.205, 371.965)" x="139.205" y="371.965">11 </text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 185.675, 378.817)" x="185.675" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 198.855, 371.965)" x="198.855" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 204.478, 371.965)" x="204.478" y="371.965">10 </text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 253.626, 378.817)" x="253.626" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 266.805, 371.965)" x="266.805" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 272.429, 371.965)" x="272.429" y="371.965">9 </text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 318.9, 378.817)" x="318.9" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 332.079, 371.965)" x="332.079" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 337.703, 371.965)" x="337.703" y="371.965">8 </text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 384.174, 378.817)" x="384.174" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 397.353, 371.965)" x="397.353" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-seri

# %% [markdown]
# ### Diagonal Noise
#
# We will use a 4x2 matrix of indepdendent linear SDEs (also known as the Black-Scholes equation)
#
# \begin{equation}
# dX_{t}=\alpha X_{t}dt+\beta X_{t}dW_{t},\thinspace\thinspace\thinspace X_{0}=\frac{1}{2}
# \end{equation}
# where $\alpha=\frac{1}{10}$ and $\beta=\frac{1}{20}$. Actual Solution:
# \begin{equation}
# X_{t}=X_{0}e^{\left(\beta-\frac{\alpha^{2}}{2}\right)t+\alpha W_{t}}.
# \end{equation}

# %%
prob = prob_sde_2Dlinear
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]

setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>SRIW1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          ]
names = ["SRIW1","EM","RKMil","SRIW1 Fixed"]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,names=names,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3800)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   142.207,360.065 142.207,11.811
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   231.444,360.065 231.444,11.811
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   320.681,360.065 320.681,11.811
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   409.918,360.065 409.918,11.811
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   499.155,360.065 499.155,11.811
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,342.077 580.315,342.077
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,266.508 580.315,266.508
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,190.938 580.315,190.938
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,115.369 580.315,115.369
#   "/>
# <polyline clip-path="url(#clip3802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,39.7997 580.315,39.7997
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   142.207,360.065 142.207,354.842
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   231.444,360.065 231.444,354.842
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   320.681,360.065 320.681,354.842
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   409.918,360.065 409.918,354.842
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   499.155,360.065 499.155,354.842
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,342.077 81.2297,342.077
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,266.508 81.2297,266.508
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,190.938 81.2297,190.938
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,115.369 81.2297,115.369
#   "/>
# <polyline clip-path="url(#clip3800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,39.7997 81.2297,39.7997
#   "/>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 128.79, 378.817)" x="128.79" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 141.969, 371.965)" x="141.969" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 147.593, 371.965)" x="147.593" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 218.027, 378.817)" x="218.027" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 231.206, 371.965)" x="231.206" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 236.83, 371.965)" x="236.83" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 307.264, 378.817)" x="307.264" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 320.443, 371.965)" x="320.443" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 326.067, 371.965)" x="326.067" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 396.501, 378.817)" x="396.501" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 409.68, 371.965)" x="409.68" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 415.304, 371.965)" x="415.304" y="371.965">3 </text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 485.738, 378.817)" x="485.738" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 498.917, 371.965)" x="498.917" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 504.541, 371.965)" x="504.541" y="371.965">2 </text>
# </g>
# <g clip-path="url(#clip3800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 348.009

# %%
prob = prob_sde_2Dlinear
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]

setups = [Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>SRI())
          Dict(:alg=>SRIW1())
          Dict(:alg=>SRIW2())
          Dict(:alg=>SOSRI())
          Dict(:alg=>SOSRI2())
          ]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   90.7048,360.065 90.7048,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   177.477,360.065 177.477,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   264.25,360.065 264.25,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   351.022,360.065 351.022,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   437.795,360.065 437.795,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   524.567,360.065 524.567,11.811
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,312.088 580.315,312.088
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,260.63 580.315,260.63
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,209.171 580.315,209.171
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,157.713 580.315,157.713
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,106.255 580.315,106.255
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,54.7962 580.315,54.7962
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   90.7048,360.065 90.7048,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.477,360.065 177.477,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   264.25,360.065 264.25,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   351.022,360.065 351.022,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   437.795,360.065 437.795,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   524.567,360.065 524.567,354.842
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,312.088 81.2297,312.088
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,260.63 81.2297,260.63
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,209.171 81.2297,209.171
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,157.713 81.2297,157.713
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,106.255 81.2297,106.255
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,54.7962 81.2297,54.7962
#   "/>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 77.2878, 378.817)" x="77.2878" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 90.467, 371.965)" x="90.467" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 96.0907, 371.965)" x="96.0907" y="371.965">7 </text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 164.06, 378.817)" x="164.06" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 177.239, 371.965)" x="177.239" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 182.863, 371.965)" x="182.863" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 250.833, 378.817)" x="250.833" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 264.012, 371.965)" x="264.012" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 269.636, 371.965)" x="269.636" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 337.605, 378.817)" x="337.605" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 350.784, 371.965)" x="350.784" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 356.408, 371.965)" x="356.408" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 424.378, 378.817)" x="424.378" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill

# %% [markdown]
# Now just the scalar Black-Scholes

# %%
prob = prob_sde_linear
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]

setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>SRIW1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          ]
names = ["SRIW1","EM","RKMil","SRIW1 Fixed"]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,names=names,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   158.136,360.065 158.136,11.811
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   246.277,360.065 246.277,11.811
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   334.419,360.065 334.419,11.811
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   422.561,360.065 422.561,11.811
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   510.703,360.065 510.703,11.811
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,332.306 580.315,332.306
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,253.02 580.315,253.02
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,173.734 580.315,173.734
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,94.4485 580.315,94.4485
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,15.1625 580.315,15.1625
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   158.136,360.065 158.136,354.842
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   246.277,360.065 246.277,354.842
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   334.419,360.065 334.419,354.842
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   422.561,360.065 422.561,354.842
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   510.703,360.065 510.703,354.842
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,332.306 81.2297,332.306
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,253.02 81.2297,253.02
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,173.734 81.2297,173.734
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,94.4485 81.2297,94.4485
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,15.1625 81.2297,15.1625
#   "/>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 144.719, 378.817)" x="144.719" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 157.898, 371.965)" x="157.898" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 163.522, 371.965)" x="163.522" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 232.86, 378.817)" x="232.86" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 246.04, 371.965)" x="246.04" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 251.663, 371.965)" x="251.663" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 321.002, 378.817)" x="321.002" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 334.182, 371.965)" x="334.182" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 339.805, 371.965)" x="339.805" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 409.144, 378.817)" x="409.144" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 422.323, 371.965)" x="422.323" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 427.947, 371.965)" x="427.947" y="371.965">3 </text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 497.286, 378.817)" x="497.286" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 510.465, 371.965)" x="510.465" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 516.089, 371.965)" x="516.089" y="371.965">2 </text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 338.238)"

# %%
setups = [Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>SRI())
          Dict(:alg=>SRIW1())
          Dict(:alg=>SRIW2())
          Dict(:alg=>SOSRI())
          Dict(:alg=>SOSRI2())
          ]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.703,360.065 102.703,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   191.213,360.065 191.213,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   279.723,360.065 279.723,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   368.233,360.065 368.233,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   456.743,360.065 456.743,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   545.253,360.065 545.253,11.811
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,347.73 580.315,347.73
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,277.729 580.315,277.729
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,207.728 580.315,207.728
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,137.727 580.315,137.727
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,67.7254 580.315,67.7254
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.703,360.065 102.703,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   191.213,360.065 191.213,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   279.723,360.065 279.723,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   368.233,360.065 368.233,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   456.743,360.065 456.743,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   545.253,360.065 545.253,354.842
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,347.73 81.2297,347.73
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,277.729 81.2297,277.729
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,207.728 81.2297,207.728
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,137.727 81.2297,137.727
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,67.7254 81.2297,67.7254
#   "/>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 89.2861, 378.817)" x="89.2861" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 102.465, 371.965)" x="102.465" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 108.089, 371.965)" x="108.089" y="371.965">7 </text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 177.796, 378.817)" x="177.796" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 190.975, 371.965)" x="190.975" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 196.599, 371.965)" x="196.599" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 266.306, 378.817)" x="266.306" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 279.485, 371.965)" x="279.485" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 285.109, 371.965)" x="285.109" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 354.816, 378.817)" x="354.816" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 367.995, 371.965)" x="367.995" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 373.619, 371.965)" x="373.619" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 443.326, 378.817)" x="443.326" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 456.505, 371.965)" x="456.505" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif

# %% [markdown]
# Now a scalar wave SDE:
#
# \begin{equation}
# dX_{t}=-\left(\frac{1}{10}\right)^{2}\sin\left(X_{t}\right)\cos^{3}\left(X_{t}\right)dt+\frac{1}{10}\cos^{2}\left(X_{t}\right)dW_{t},\thinspace\thinspace\thinspace X_{0}=\frac{1}{2}
# \end{equation}
# Actual Solution:
# \begin{equation}
# X_{t}=\arctan\left(\frac{1}{10}W_{t}+\tan\left(X_{0}\right)\right).
# \end{equation}

# %%
prob = prob_sde_wave
prob = SDEProblem(prob.f,prob.g,prob.u0,(0.0,1.0))

reltols = 1.0./10.0.^(1:5)
abstols = reltols#[0.0 for i in eachindex(reltols)]

setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 1))
          Dict(:alg=>SRIW1(),:dts=>1.0./5.0.^((1:length(reltols)) + 1),:adaptive=>false)
          ]
names = ["SRIW1","EM","RKMil","SRIW1 Fixed"]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,names=names,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 80.219,360.065 580.315,360.065 580.315,11.811 80.219,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="80" y="11" width="501" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   193.659,360.065 193.659,11.811
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   308.72,360.065 308.72,11.811
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   423.781,360.065 423.781,11.811
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   538.843,360.065 538.843,11.811
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,324.888 580.315,324.888
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,272.633 580.315,272.633
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,220.379 580.315,220.379
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,168.125 580.315,168.125
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,115.871 580.315,115.871
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   80.219,63.6168 580.315,63.6168
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,360.065 80.219,11.811
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   193.659,360.065 193.659,354.842
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.72,360.065 308.72,354.842
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   423.781,360.065 423.781,354.842
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   538.843,360.065 538.843,354.842
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,324.888 87.7205,324.888
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,272.633 87.7205,272.633
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,220.379 87.7205,220.379
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,168.125 87.7205,168.125
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,115.871 87.7205,115.871
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.219,63.6168 87.7205,63.6168
#   "/>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 180.242, 378.817)" x="180.242" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 193.421, 371.965)" x="193.421" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 199.045, 371.965)" x="199.045" y="371.965">7 </text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 295.303, 378.817)" x="295.303" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 308.482, 371.965)" x="308.482" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 314.106, 371.965)" x="314.106" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 410.364, 378.817)" x="410.364" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 423.544, 371.965)" x="423.544" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 429.167, 371.965)" x="429.167" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 525.426, 378.817)" x="525.426" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 538.605, 371.965)" x="538.605" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 544.229, 371.965)" x="544.229" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 33.9998, 330.82)" x="33.9998" y="330.82">10</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 47.179, 323.967)" x="47.179" y="323.967">-</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 52.8027, 323.967)" x="52.8027" y="323.967">3.50 </text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 33.9998, 278.565)" x="33.9998"

# %% [markdown]
# Note that in this last problem, the adaptivity algorithm accurately detects that the error is already low enough, and does not increase the number of steps as the tolerance drops further.

# %%
setups = [Dict(:alg=>EM(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>RKMil(),:dts=>1.0./5.0.^((1:length(reltols)) + 2))
          Dict(:alg=>SRI())
          Dict(:alg=>SRIW1())
          Dict(:alg=>SRIW2())
          Dict(:alg=>SOSRI())
          Dict(:alg=>SOSRI2())
          ]
wp = WorkPrecisionSet(prob,abstols,reltols,setups;numruns=1000,error_estimate=:l2)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   152.479,360.065 152.479,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   258.007,360.065 258.007,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   363.534,360.065 363.534,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   469.061,360.065 469.061,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   574.588,360.065 574.588,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,341.538 580.315,341.538
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,267.022 580.315,267.022
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,192.507 580.315,192.507
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,117.992 580.315,117.992
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,43.4766 580.315,43.4766
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   152.479,360.065 152.479,354.842
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   258.007,360.065 258.007,354.842
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   363.534,360.065 363.534,354.842
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   469.061,360.065 469.061,354.842
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   574.588,360.065 574.588,354.842
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,341.538 81.2297,341.538
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,267.022 81.2297,267.022
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,192.507 81.2297,192.507
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,117.992 81.2297,117.992
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,43.4766 81.2297,43.4766
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 139.062, 378.817)" x="139.062" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 152.242, 371.965)" x="152.242" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 157.865, 371.965)" x="157.865" y="371.965">8 </text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 244.59, 378.817)" x="244.59" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 257.769, 371.965)" x="257.769" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 263.392, 371.965)" x="263.392" y="371.965">7 </text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 350.117, 378.817)" x="350.117" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 363.296, 371.965)" x="363.296" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 368.92, 371.965)" x="368.92" y="371.965">6 </text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 455.644, 378.817)" x="455.644" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 468.823, 371.965)" x="468.823" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 474.447, 371.965)" x="474.447" y="371.965">5 </text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 561.171, 378.817)" x="561.171" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 574.35, 371.965)" x="574.35" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 579.974, 371.965)" x="579.974" y="371.965">4 </text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 347.47)

# %% [markdown]
# ### Conclusion
#
# The RSwM3 adaptivity algorithm does not appear to have any significant overhead even on problems which do not necessitate adaptive timestepping. The tolerance clearly  In addition, the Rossler methods are shown to be orders of magnitude more efficient and should be used whenever applicable. The Oval2 tests show that these results are only magnified as the problem difficulty increases.
