# %%
using StochasticDiffEq, DiffEqDevTools, ParameterizedFunctions, DiffEqProblemLibrary
using Plots; gr()
f = @ode_def LotkaVolterraTest begin
  dx = a*x - b*x*y
  dy = -c*y + d*x*y
end a b c d

p = [1.5,1.0,3.0,1.0]

function g(du,u,p,t)
  du .= 0.1u
end
u0 = [1.0;1.0]
tspan = (0.0,10.0)
prob = SDEProblem(f,g,u0,tspan,p);
# Out:
# INFO: Recompiling stale cache file /home/crackauc/.julia/lib/v0.6/StochasticDiffEq.ji for module StochasticDiffEq.

# %%
sol = solve(prob,SRIW1(),abstol=1e-4,reltol=1e-4)
plot(sol)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 22.3377,360.065 580.315,360.065 580.315,11.811 22.3377,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="22" y="11" width="559" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,360.065 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   133.933,360.065 133.933,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   245.529,360.065 245.529,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   357.124,360.065 357.124,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   468.72,360.065 468.72,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,360.065 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,319.341 580.315,319.341
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,263.076 580.315,263.076
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,206.81 580.315,206.81
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,150.545 580.315,150.545
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,94.2794 580.315,94.2794
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,38.014 580.315,38.014
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,360.065 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,360.065 22.3377,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   133.933,360.065 133.933,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   245.529,360.065 245.529,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   357.124,360.065 357.124,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   468.72,360.065 468.72,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,354.842
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,319.341 30.7073,319.341
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,263.076 30.7073,263.076
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,206.81 30.7073,206.81
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,150.545 30.7073,150.545
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,94.2794 30.7073,94.2794
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,38.014 30.7073,38.014
#   "/>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 22.3377, 373.865)" x="22.3377" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 133.933, 373.865)" x="133.933" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 245.529, 373.865)" x="245.529" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 357.124, 373.865)" x="357.124" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 468.72, 373.865)" x="468.72" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 323.841)" x="16.3377" y="323.841">1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 267.576)" x="16.3377" y="267.576">2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 211.31)" x="16.3377" y="211.31">3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 155.045)" x="16.3377" y="155.045">4</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 98.7794)" x="16.3377" y="98.7794">5</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 42.514)" x="16.3377" y="42.514">6</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 301.326, 397.6)" x="301.326" y="397.6">t</text>
# </g>
# <polyline clip-path="url(#clip1602)" style="stroke:#009af9; stroke-width:3; stroke-op

# %% [markdown]
# ## Strong Error

# %% [markdown]
# The starting `dt`s was chosen as the largest in the `1/4^i` which were stable. All larger `dt`s contained trajectories which would veer off to infinity.

# %%
reltols = 1.0./4.0.^(2:4)
abstols = reltols#[0.0 for i in eachindex(reltols)]
setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./12.0.^((1:length(reltols)) + 1.5))
          Dict(:alg=>RKMil(),:dts=>1.0./12.0.^((1:length(reltols)) + 1.5))
          Dict(:alg=>SRIW1(),:dts=>1.0./4.0.^((1:length(reltols)) + 5),:adaptive=>false)
          Dict(:alg=>SRIW2())
          Dict(:alg=>SOSRI())
          Dict(:alg=>SOSRI2())
          ]
test_dt = 1/10^2
appxsol_setup = Dict(:alg=>SRIW1(),:abstol=>1e-4,:reltol=>1e-4)
wp = WorkPrecisionSet(prob,abstols,reltols,setups,test_dt;
                                     verbose=false,save_everystep=false,
                                     parallel_type = :threads,
                                     appxsol_setup = appxsol_setup,
                                     numruns_error=100,error_estimate=:final)
plot(wp)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6000)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.794,360.065 102.794,11.811
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   232.691,360.065 232.691,11.811
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   362.588,360.065 362.588,11.811
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   492.485,360.065 492.485,11.811
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,358.302 580.315,358.302
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,296.967 580.315,296.967
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,235.632 580.315,235.632
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,174.297 580.315,174.297
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,112.962 580.315,112.962
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,51.6266 580.315,51.6266
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.794,360.065 102.794,354.842
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   232.691,360.065 232.691,354.842
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   362.588,360.065 362.588,354.842
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   492.485,360.065 492.485,354.842
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,358.302 81.2297,358.302
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,296.967 81.2297,296.967
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,235.632 81.2297,235.632
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,174.297 81.2297,174.297
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,112.962 81.2297,112.962
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,51.6266 81.2297,51.6266
#   "/>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 85.3619, 378.817)" x="85.3619" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 98.5411, 371.965)" x="98.5411" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 104.165, 371.965)" x="104.165" y="371.965">2.5 </text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 215.259, 378.817)" x="215.259" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 228.438, 371.965)" x="228.438" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 234.062, 371.965)" x="234.062" y="371.965">2.0 </text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 345.156, 378.817)" x="345.156" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 358.335, 371.965)" x="358.335" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 363.959, 371.965)" x="363.959" y="371.965">1.5 </text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 475.053, 378.817)" x="475.053" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 488.232, 371.965)" x="488.232" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 493.856, 371.965)" x="493.856" y="371.965">1.0 </text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 32.7642, 364.234)" x="32.7642" y="364.234">10</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.9435, 357.382)" x="45.9435" y="357.382">-</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.5672, 357.382)" x="51.5672" y="357.382">3.5 </text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0,

# %% [markdown]
# ## Weak Error

# %%
reltols = 1.0./4.0.^(2:4)
abstols = reltols#[0.0 for i in eachindex(reltols)]
setups = [Dict(:alg=>SRIW1())
          Dict(:alg=>EM(),:dts=>1.0./12.0.^((1:length(reltols)) + 1.5))
          Dict(:alg=>RKMil(),:dts=>1.0./12.0.^((1:length(reltols)) + 1.5))
          Dict(:alg=>SRIW1(),:dts=>1.0./4.0.^((1:length(reltols)) + 5),:adaptive=>false)
          Dict(:alg=>SRIW2())
          Dict(:alg=>SOSRI())
          Dict(:alg=>SOSRI2())
          ]
test_dt = 1e-2
appxsol_setup = Dict(:alg=>SRIW1(),:abstol=>1e-4,:reltol=>1e-4)
wp = WorkPrecisionSet(prob,abstols,reltols,setups,test_dt;
                                     verbose=false,save_everystep=false,
                                     parallel_type = :threads,
                                     appxsol_setup = appxsol_setup,
                                     numruns_error=100,error_estimate=:weak_final)
plot(wp;legend=:topleft)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   117.091,360.065 117.091,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   208.843,360.065 208.843,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   300.596,360.065 300.596,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   392.348,360.065 392.348,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   484.101,360.065 484.101,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   575.853,360.065 575.853,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,299.074 580.315,299.074
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,237.171 580.315,237.171
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,175.269 580.315,175.269
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,113.366 580.315,113.366
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,51.4632 580.315,51.4632
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   117.091,360.065 117.091,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   208.843,360.065 208.843,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.596,360.065 300.596,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   392.348,360.065 392.348,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   484.101,360.065 484.101,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   575.853,360.065 575.853,354.842
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,299.074 81.2297,299.074
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,237.171 81.2297,237.171
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,175.269 81.2297,175.269
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,113.366 81.2297,113.366
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,51.4632 81.2297,51.4632
#   "/>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 99.6582, 378.817)" x="99.6582" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 112.837, 371.965)" x="112.837" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 118.461, 371.965)" x="118.461" y="371.965">3.0 </text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 191.411, 378.817)" x="191.411" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 204.59, 371.965)" x="204.59" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 210.214, 371.965)" x="210.214" y="371.965">2.5 </text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 283.163, 378.817)" x="283.163" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 296.342, 371.965)" x="296.342" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 301.966, 371.965)" x="301.966" y="371.965">2.0 </text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 374.915, 378.817)" x="374.915" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 388.095, 371.965)" x="388.095" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 393.718, 371.965)" x="393.718" y="371.965">1.5 </text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 466.668, 378.817)" x="466.668" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 479.847, 371.965)" x="479.847" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,

# %%
sample_size = Int[10;1e2;1e3;1e4;1e5]
test_dt = 1e-2
appxsol_setup = Dict(:alg=>SRIW1(),:abstol=>1e-4,:reltol=>1e-4)
se = get_sample_errors(prob,test_dt,appxsol_setup=appxsol_setup,
parallel_type = :threads, numruns=sample_size, std_estimation_runs = Int(1e3))
# Out:
# 5-element Array{Float64,1}:
#  0.695391
#  0.219902
#  0.0695391
#  0.0219902
#  0.00695391

# %%
plot(wp;legend=:topleft)
times = [wp[i].times for i in 1:length(wp)]
times = [minimum(minimum(t) for t in times),maximum(maximum(t) for t in times)]
plot!([se[end];se[end]],times,color=:orange,linestyle=:dash,label="Sample Error: 10000",lw=3)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6400)" points="
# 73.6294,360.065 580.315,360.065 580.315,11.811 73.6294,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="73" y="11" width="508" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   117.091,360.065 117.091,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   208.843,360.065 208.843,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   300.596,360.065 300.596,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   392.348,360.065 392.348,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   484.101,360.065 484.101,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   575.853,360.065 575.853,11.811
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,299.074 580.315,299.074
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,237.171 580.315,237.171
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,175.269 580.315,175.269
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,113.366 580.315,113.366
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.6294,51.4632 580.315,51.4632
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,360.065 73.6294,11.811
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   117.091,360.065 117.091,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   208.843,360.065 208.843,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.596,360.065 300.596,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   392.348,360.065 392.348,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   484.101,360.065 484.101,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   575.853,360.065 575.853,354.842
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,299.074 81.2297,299.074
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,237.171 81.2297,237.171
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,175.269 81.2297,175.269
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,113.366 81.2297,113.366
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.6294,51.4632 81.2297,51.4632
#   "/>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 99.6582, 378.817)" x="99.6582" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 112.837, 371.965)" x="112.837" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 118.461, 371.965)" x="118.461" y="371.965">3.0 </text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 191.411, 378.817)" x="191.411" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 204.59, 371.965)" x="204.59" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 210.214, 371.965)" x="210.214" y="371.965">2.5 </text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 283.163, 378.817)" x="283.163" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 296.342, 371.965)" x="296.342" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 301.966, 371.965)" x="301.966" y="371.965">2.0 </text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 374.915, 378.817)" x="374.915" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 388.095, 371.965)" x="388.095" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 393.718, 371.965)" x="393.718" y="371.965">1.5 </text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 466.668, 378.817)" x="466.668" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 479.847, 371.965)" x="479.847" y="371.965">-</text>
# </g>
# <g clip-path="url(#clip6400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,

# %% [markdown]
# ## Conclusion
#
# These results show that in both strong and weak error, the high order method is more efficient. The strong and the weak are track each other well for the methods tested on this problem, with the strong error slightly higher than the weak error. To reach the sample error for a 100 trajectories, the higher order method is around 5x faster. To reach the sampling error for 10000 trajectories, the higher order method is nearly 100x faster.
